# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# !apt install -y fonts-nanum
# !fc-cache -fv

applyfont = "NanumBarunGothic"

import matplotlib.font_manager as fm
if not any(map(lambda ft: ft.name == applyfont, fm.fontManager.ttflist)):
    fm.fontManager.addfont("/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf")

plt.rc("font", family=applyfont)
plt.rc("axes", unicode_minus=False)
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 1s (11.8 MB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 122541 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20180306-3_all.deb ...
# Unpacking fonts-nanum (20180306-3) ...
# Setting up fonts-nanum (20180306-3) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# ...

# %%
play1 = True
play2 = True
play8 = True


while play1:
    
    try:
        play3 = True
        play4 = True
        play5 = True
        play6 = True
        play7 = True
        start = int(input("""
안녕하세요, NBA 데이터 제공 프로그램입니다. 실행하고자 하는 항목의 번호를 입력해주세요.

1. 20-21, 21-22, 22-23시즌의 리그 순위 및 기본 정보 제공(승률, PS/G, PA/G)
2. 20-21, 21-22, 22-23시즌의 MVP,  DPOY, MIP, 올해의 감독상 수상한 인물과 그 stats 제공
3. 역대 180클럽 가입자 정보(야투율 + 3점슛 + 자유투) 제공
4. 20-21, 21-22, 22-23시즌의 득점/리바운드/어시스트/스틸/블락 TOP 5선수의 stats 제공
        """))
        if start == 1:
            while play3:
                play3 = True
                play4 = True
                play5 = True
                play6 = True
                play7 = True
                try:
                    k1_1 = int(input("""
리그를 선택하세요.

1. 서부 순위 
2. 동부 순위
                    """))
                    
                    if k1_1 == 1:
                        df_1 = pd.read_csv('/content/3시즌 팀 순위+기본정보.서부만.csv', encoding = 'cp949')
                        while True:
                            try:

                                k1_2 = int(input(""" 
시즌을 선택하세요

1. 20-21 시즌
2. 21-22 시즌
3, 22-23 시즌
                                """))
                            
                                if k1_2 == 1:
                                    season_1_1 = df_1[33:48]
                                    print(season_1_1)
                                    play3 = False
                                    break
                                    
                                elif k1_2 == 2:
                                    season_1_2 = df_1[17:32]   
                                    print(season_1_2)
                                    play3 = False
                                    break
                                    
                                elif k1_2 == 3:
                                    season_1_3 = df_1[1:16]  
                                    print(season_1_3)
                                    play3 = False
                                    break
                                    
                                else:
                                    print('주어진 숫자 안에서 입력하세요.')
                                    continue
                                
                            except ValueError:
                                print('숫자를 입력하세요.')
                                continue
                            
                    elif k1_1 == 2:
                        df_2 = pd.read_csv('/content/3시즌 팀 순위+기본정보.동부만.csv', encoding = 'cp949')
                        
                        while True:
                            try:
                                k2_2 = int(input(""" 
시즌을 선택하세요

1. 20-21 시즌
2. 21-22 시즌
3, 22-23 시즌
                        """))
                                if k2_2 == 1:
                                    season_2_1 = df_2[33:48]
                                    print(season_2_1)
                                    play3 = False
                                    break

                                elif k2_2 == 2:
                                    season_2_2 = df_2[17:32]   
                                    print(season_2_2)
                                    play3 = False
                                    break

                                elif k2_2 == 3:
                                    season_2_3 = df_2[1:16]  
                                    print(season_2_3)
                                    play3 = False
                                    break

                                else:
                                    print('주어진 숫자 안에서 입력하세요.')
                                    continue
                            except ValueError:
                                print('숫자를 입력하세요.')
                                continue
                    else:
                        print('주어진 숫자 안에서만 입력하세요.')
                        continue

                except ValueError:
                    print('숫자를 입력하세요.')
                    continue

        elif start == 2:
            while play4:
                try:
                    a = int(input(""" 
수상 종류를 선택하세요.

1. MVP
2. DPOY
3. MIP
4.COY
                    """))
                    while play5:
                        try:
                            df_3 = pd.read_csv('/content/수상자와 스탯.기본정보만.csv', encoding = 'cp949')
                            df_4 = pd.read_csv('/content/수상자와 스탯.COY기본정보만.csv', encoding = 'cp949')
                            if a == 1:
                                df_3_1 = df_3[1:4]
                                while True:
                                    try:
                                        s_1 = int(input(""" 
시즌을 선택하세요

1. 20-21 시즌
2. 21-22 시즌
3, 22-23 시즌
                                        """))
                                    
                                        if s_1 == 1:
                                            print(df_3_1[0:1])
                                            play4 = False
                                            play5 = False
                                            break
                                        elif s_1 == 2:
                                            print(df_3_1[1:2])
                                            play4 = False
                                            play5 = False
                                            break
                                        elif s_1 == 3:
                                            print(df_3_1[2:3])
                                            play4 = False
                                            play5 = False
                                            break
                                        else:
                                            print('주어진 숫자만 입력하세요.')
                                            continue
                                            
                                    except ValueError:
                                        print('숫자를 입력하세요.')
                                        continue
                                    

                            elif a == 2:
                                df_3_2 = df_3[5:8]
                                while True:
                                    try:
                                        s_2 = int(input(""" 
시즌을 선택하세요

1. 20-21 시즌
2. 21-22 시즌
3, 22-23 시즌
                                        """))
                                    
                                        if s_2 == 1:
                                            print(df_3_2[0:1])
                                            play4 = False
                                            play5 = False
                                            break
                                        elif s_2 == 2:
                                            print(df_3_2[1:2])
                                            play4 = False
                                            play5 = False
                                            break
                                        elif s_2 == 3:
                                            print(df_3_2[2:3])
                                            play4 = False
                                            play5 = False
                                            break
                                        else:
                                            print('주어진 숫자만 입력하세요.')
                                            continue

                                    except ValueError:
                                        print('숫자를 입력하세요.')
                                        continue


                            elif a == 3:
                                df_3_3 = df_3[9:12]
                                while True:
                                    try:
                                        s_3 = int(input(""" 
시즌을 선택하세요

1. 20-21 시즌
2. 21-22 시즌
3, 22-23 시즌
                                        """))
                                    
                                        if s_3 == 1:
                                            print(df_3_3[0:1])
                                            play4 = False
                                            play5 = False
                                            break
                                        elif s_3 == 2:
                                            print(df_3_3[1:2])
                                            play4 = False
                                            play5 = False
                                            break
                                        elif s_3 == 3:
                                            print(df_3_3[2:3])
                                            play4 = False
                                            play5 = False
                                            break
                                        else:
                                            print('주어진 숫자만 입력하세요.')
                                            continue
                                            
                                    except ValueError:
                                        print('숫자를 입력하세요.')
                                        continue
                                    
                                
                            elif a == 4:
                                while True:
                                    try:
                                        s_4 = int(input(""" 
시즌을 선택하세요

1. 20-21 시즌
2. 21-22 시즌
3, 22-23 시즌
                                        """)) 
                                    
                                        if s_4 == 1:
                                            print(df_4[0:1])
                                            play4 = False
                                            play5 = False
                                            break
                                        elif s_4 == 2:
                                            print(df_4[1:2])
                                            play4 = False
                                            play5 = False
                                            break
                                        elif s_4 == 3:
                                            print(df_4[2:3])
                                            play4 = False
                                            play5 = False
                                            break
                                        else:
                                            print('주어진 숫자만 입력하세요.')
                                            continue
                                            
                                    except ValueError:
                                        print('숫자를 입력하세요.')
                                        continue                                

                            else:
                                print('주어진 숫자 안에서만 입력하세요.')
                                break
                                
                        except ValueError:
                            print('숫자를 입력하세요')

                            continue
                except ValueError:
                    print('숫자만 입력하세요')
                    continue
                    
        elif start == 3:
            b = pd.read_csv('/content/180클럽 가입자.csv', encoding = 'cp949')
            print(b)
            
        elif start == 4:
            while play6:
                try:
                    ss = int(input(""" 
시즌을 선택하세요

1. 20-21 시즌
2. 21-22 시즌
3, 22-23 시즌
                            """)) 
                    c = pd.read_csv('/content/top5 선수 스탯 최종 수정본.csv', encoding = 'cp949')
                    while play7:
                        if ss == 1:
                            c_1 = c[1:31]
                            while True:
                                try:
                                    ss_1 = int(input(""" 
스탯을 선택하세요

1. 득점
2. 리바운드
3, 어시스트
4. 스틸
5. 블락
                                    """))
                            
                                    if ss_1 == 1:
                                        c_1_1 = c_1[1:6]
                                        print(c_1_1)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_1 == 2:
                                        c_1_2 = c_1[7:12]
                                        print(c_1_2)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_1 == 3:
                                        c_1_3 = c_1[13:18]
                                        print(c_1_3)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_1 == 4:
                                        c_1_4 = c_1[19:24]
                                        print(c_1_4)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_1 == 5:
                                        c_1_5 = c_1[25:30]
                                        print(c_1_5)
                                        play6 = False
                                        play7 = False
                                        break
                                    else:
                                        print('주어진 숫자 안에서 입력하세요.')
                                        continue
                                        
                                except ValueError:
                                    print('숫자를 입력하세요.')
                                    continue
                        elif ss == 2:
                            c_2 = c[32:62]
                            while True:
                                try:
                                    ss_2 = int(input(""" 
스탯을 선택하세요

1. 득점
2. 리바운드
3, 어시스트
4. 스틸
5. 블락
                                    """))
                                
                                    if ss_2 == 1:
                                        c_2_1 = c_2[1:6]
                                        print(c_2_1)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_2 == 2:
                                        c_2_2 = c_2[7:12]
                                        print(c_2_2)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_2 == 3:
                                        c_2_3 = c_2[13:18]
                                        print(c_2_3)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_2 == 4:
                                        c_2_4 = c_2[19:24]
                                        print(c_2_4)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_2 == 5:
                                        c_2_5 = c_2[25:30]
                                        print(c_2_5)
                                        play6 = False
                                        play7 = False
                                        break
                                    else:
                                        print('주어진 숫자 안에서 입력하세요.')
                                        continue
                                        

                                except ValueError:
                                    print('숫자를 입력하세요.')
                                    continue
                        elif ss == 3:
                            c_3 = c[63:93]
                            while True:
                                try:
                                    ss_3 = int(input(""" 
스탯을 선택하세요

1. 득점
2. 리바운드
3, 어시스트
4. 스틸
5. 블락
                                    """))
                                
                                    if ss_3 == 1:
                                        c_3_1 = c_3[1:6]
                                        print(c_3_1)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_3 == 2:
                                        c_3_2 = c_3[7:12]
                                        print(c_3_2)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_3 == 3:
                                        c_3_3 = c_3[13:18]
                                        print(c_3_3)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_3 == 4:
                                        c_3_4 = c_3[19:24]
                                        print(c_3_4)
                                        play6 = False
                                        play7 = False
                                        break
                                    elif ss_3 == 5:
                                        c_3_5 = c_3[25:30]
                                        print(c_3_5)
                                        play6 = False
                                        play7 = False
                                        break
                                    else:
                                        print('주어진 숫자 안에서 입력하세요.')
                                        continue
                                        

                                except ValueError:
                                    print('숫자를 입력하세요.')
                                    continue
                        else:
                            print('주어진 숫자 안에서만 입력하세요.')
                            break

                except ValueError:
                    print('숫자를 입력하세요.')
                    continue

                    
        else:
            print('주어진 숫자 범위 내에서 입력하세요')
            continue
                
    except ValueError:
        print('숫자를 입력하세요')
        continue
        

    while play2:
        prog_end_1 = input("""
검색을 계속 하시겠습니까? (y/n) """)
        
        if prog_end_1 == 'n' or prog_end_1 == 'N':
            while play8:
                prog_end_2 = input("""
본 프로그램은 NBA관련 상관관계를 분석한 데이터를 가지고 있습니다. 상관관계를 알아보시겠습니까? (y/n)""")
                while True:
                        try:
                        
                            if prog_end_2 == 'y' or prog_end_2 == 'Y':
                                corr_q = int(input("""
본 프로그램에서 제시하는 상관관계 목록입니다. 알아보고자 하는 항목의 번호를 입력해주세요.

1. 팀 전체 리바운드 수와 팀 순위 간의 상관관계 (22-23시즌 데이터 기반)
2. 특정 팀의 평균 득실차와 정규시즌 순위와의 상관관계
                            """))

                                if corr_q == 1:
                                    correl1 = pd.read_csv('/content/리바운드와 팀순위 수정본.csv', encoding = 'cp949')
                                    correl1.rename(columns={'Unnamed: 0':'팀 순위', '팀_':'팀명'}, inplace = True)
                                    correl1

                                    plt.scatter(correl1['팀 순위'], correl1['리바운드'])
                                    plt.xlabel('팀 순위')
                                    plt.ylabel('팀 전체 리바운드 수')
                                    plt.title('22-23시즌 리바운드 수와 팀 순위 산점도')

                                    for i, team in enumerate(correl1['팀명']):
                                        plt.annotate(team, (correl1['팀 순위'][i], correl1['리바운드'][i]), fontsize = 7)
                                    plt.pause(0.1)
                                    plt.show()
                                    break
                                    
                                elif corr_q == 2:
                                    cor4 = pd.read_csv('/content/팀 순위와 평균 득실 차 수정본.csv', encoding = 'cp949')
                                    cor4.rename(columns={'Unnamed: 0':'팀 순위'}, inplace = True)
                                    cor4

                                    plt.scatter(cor4['팀 순위'], cor4['평균 득실 차'])
                                    plt.xlabel('팀 순위')
                                    plt.ylabel('팀 평균 득실 차')
                                    plt.title('팀 평균 득실 차와 팀 순위 상관관계')
                                    plt.xticks(cor4['팀 순위'])

                                    for i, team in enumerate(cor4['팀명']):
                                        plt.annotate(team, (cor4['팀 순위'][i], cor4['평균 득실 차'][i]), fontsize = 7)
                                    plt.pause(0.1)
                                    plt.show()
                                    break

                                else:
                                    print('주어진 숫자 범위 내에서 입력하세요')
                                    continue                        

                            elif prog_end_2 == 'n' or prog_end_2 == 'N':
                                print('프로그램을 종료합니다.')
                                play1 = False
                                play2 = False
                                play8 = False
                                break
                                
                            else:
                                print('y와 n 중에서만 입력해주세요')
                                continue
                        except ValueError:
                            print('숫자를 입력하세요')

        elif prog_end_1 == 'y' or prog_end_1 == 'Y':
            play8 = False
            break
        else:
            print('y와 n 중에서만 입력해주세요')
# Out:
# 안녕하세요, NBA 데이터 제공 프로그램입니다. 실행하고자 하는 항목의 번호를 입력해주세요.
#
# 1. 20-21, 21-22, 22-23시즌의 리그 순위 및 기본 정보 제공(승률, PS/G, PA/G)
# 2. 20-21, 21-22, 22-23시즌의 MVP,  DPOY, MIP, 올해의 감독상 수상한 인물과 그 stats 제공
# 3. 역대 180클럽 가입자 정보(야투율 + 3점슛 + 자유투) 제공
# 4. 20-21, 21-22, 22-23시즌의 득점/리바운드/어시스트/스틸/블락 TOP 5선수의 stats 제공
#         4
#
# 시즌을 선택하세요
#
# 1. 20-21 시즌
# 2. 21-22 시즌
# 3, 22-23 시즌
#                             3
#
# 스탯을 선택하세요
#
# 1. 득점
# 2. 리바운드
# 3, 어시스트
# 4. 스틸
# 5. 블락
#                                     g
# 숫자를 입력하세요.
#
# 스탯을 선택하세요
#
# 1. 득점
# 2. 리바운드
# 3, 어시스트
# 4. 스틸
# 5. 블락
#                                     1
#                       PLAYER TEAM   AGE    GP     W     L   MIN   PTS   FGM  \
# 64  1          Stephen Curry  GSW  33.0  63.0  37.0  26.0  34.2  32.0  10.4
# 65  2           Bradley Beal  WAS  28.0  60.0  32.0  28.0  35.8  31.3  11.2
# 66  3         Damian Lillard  POR  30.0  67.0  39.0  28.0  35.8  28.8   9.0
# ...
